# %%
from bs4 import BeautifulSoup
import requests

# %%
r = requests.get('https://razorpay.slack.com/stats#members')

# %%
print(r.text)
# Out:
# <!DOCTYPE html><html lang="en-US" class=""><head><script type="text/javascript" src="https://a.slack-edge.com/bv1-8-8cacda2/webpack.manifest.c98674ffb0ede734d1fa.min.js" onload="window._cdn ? _cdn.ok(this, arguments) : null" onerror="window._cdn ? _cdn.failed(this, arguments) : null" crossorigin="anonymous"></script><script>window.ts_endpoint_url = "https:\/\/slack.com\/beacon\/timing";(function(e) {
# ...

# %%
soup = BeautifulSoup(r.text,'html.parser')

# %%
results = soup.find_all('span', attrs={'class':'ent_data_table__primary_text'})

# %%
results
# Out:
# []
